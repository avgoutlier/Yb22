# %% [markdown]
# ## Import Packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from mpl_toolkits.mplot3d import Axes3D
import torch
import torch.nn as nn
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Setup a Device

# %%
# Device configuration
if torch.cuda.is_available():
  device = torch.device('cuda')
else:
  device = torch.device('cpu')
  
print('device:', device)
# Out:
# device: cuda

# %% [markdown]
# ## Function

# %%
'''
# function_2d
# Input : x , y
# output : z = f(x,y)
'''
def function_2d(x,y):
  term_sqrt = np.sqrt(x*x+y*y)
  term1 = np.sin(20*term_sqrt)/(20*term_sqrt)
  term2 = (1/5)*np.cos(10*term_sqrt)
  term3 = y/2 - 0.3
  
  label = term1 + term2 + term3
  return label

'''
# generate_data
# input : dim (int)
# output : (10000, 3) dataset, type : np.array
- first column : x
- second column : y
- third column : f(x,y) (True label)
'''
def generate_data(dim):
  x = np.linspace(-1, 1, dim)
  y = np.linspace(-1, 1, dim)
  xx, yy = np.meshgrid(x,y)
  zz = function_2d(xx,yy)
  zz = zz

  data_1 = xx.reshape(-1,1)
  data_2 = yy.reshape(-1,1)
  label = zz.reshape(-1,1)

  dataset = np.hstack((data_1, data_2))
  dataset = np.hstack((dataset, label))

  return dataset

# %% [markdown]
# ## Function Plot

# %%
fig = plt.figure(figsize=(9, 6))
ax = fig.add_subplot(111, projection='3d')
x = np.linspace(-1, 1, 100)
y = np.linspace(-1, 1, 100)
xx, yy = np.meshgrid(x,y)
zz = function_2d(xx,yy)
surf = ax.plot_surface(xx, yy, zz, cmap='viridis')
surf.set_clim(-1.0, 1.0)
ax.view_init(30,-60)
ax.set_zticks([-1,1])
ax.zaxis.set_major_locator(ticker.MultipleLocator(0.25))
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Load Data

# %%
class Mydataset(torch.utils.data.Dataset):

  def __init__(self, dataX_np , dataY_np):

    self.data_X = dataX_np.astype(np.float32)
    self.data_Y = dataY_np.astype(np.float32)

    print(f"My_dataset __init__ received : {self.data_X.shape}, {self.data_Y.shape} ")

  def __getitem__(self, index):
    batch = self.data_X[index]
    target = self.data_Y[index]

    return batch, target

  def __len__(self):
    return len(self.data_X)

# %%
dataset = generate_data(100)

# %% [markdown]
# ## Train, Valid, Test data split

# %%
x = dataset[:, :2]
y = dataset[:,2:]

# train-test 분리
x_train, x_temp, y_train, y_temp = train_test_split(x,y,test_size=0.3, shuffle=True)

# train-validation 분리
x_val, x_test, y_val, y_test = train_test_split(x_temp, y_temp, test_size=0.5,shuffle=True)

print(x_train.shape)
print(x_val.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (7000, 2)
# (1500, 2)
# (1500, 2)
# (1500, 1)

# %% [markdown]
# ## Model Architecture

# %%
class SimpleMLP(nn.Module):

  def __init__(self):
    super(SimpleMLP, self).__init__()
    self.fc1 = nn.Linear(2, 512, bias=True)
    self.bn1 = nn.BatchNorm1d(num_features=512)
    self.fc2 = nn.Linear(512, 256, bias=True)
    self.bn2 = nn.BatchNorm1d(num_features=256)
    self.fc3 = nn.Linear(256, 1, bias=True)

  def forward(self, x):
    x = self.fc1(x)
    x = self.bn1(x)
    x = torch.nn.functional.tanh(x)
    x = self.fc2(x)
    x = self.bn2(x)
    x = torch.nn.functional.tanh(x)
    x = self.fc3(x)

    return x

# %% [markdown]
# ## Setting DataLoader

# %%
batch_size = 1000000
train_loader = torch.utils.data.DataLoader(Mydataset(x_train, y_train), batch_size=batch_size, shuffle=True, drop_last = False)
valid_loader = torch.utils.data.DataLoader(Mydataset(x_val, y_val), batch_size=batch_size, shuffle=True, drop_last = False)
test_loader = torch.utils.data.DataLoader(Mydataset(x_test, y_test), batch_size=batch_size, shuffle=True, drop_last = False)
# Out:
# My_dataset __init__ received : (7000, 2), (7000, 1)
# My_dataset __init__ received : (1500, 2), (1500, 1)
# My_dataset __init__ received : (1500, 2), (1500, 1)

# %% [markdown]
# ## Training

# %%
from statistics import mean
import time

def train(model, criterion_, optimizer_, scheduler_, num_epochs=20, first_epoch=1):
    
    train_losses = []
    valid_losses = []
    test_losses = []

    print("----------------------------------------------------------------------------")

    start_time = time.time()
    for epoch in range(first_epoch, first_epoch + num_epochs):
        # train phase
        model.train()
        
        # batch_loss 
        batch_losses = []

        for images, labels in train_loader:
            
            # Move the training data to the GPU
            images = images.to(device)   
            labels = labels.to(device)

            # clear previous gradient computation
            optimizer_.zero_grad()

            # forward propagation
            outputs = model(images)

            # calculate the loss
            loss = criterion_.forward(outputs, labels)
            batch_losses.append(loss.item())

            # backpropagate to compute gradients
            loss.backward()

            # update model weights
            optimizer_.step()

        # Train loss를 저장합니다.
        train_losses.append(mean(batch_losses))

        # validation phase
        # Dropout, BatchNormalization과 같은 layer가 동작하지 않도록 합니다.
        model.eval()

        # We don't need gradients for test, so wrap in 
        # no_grad to save memory
        # 기울기 Gradient를 계산하지 않으며 backpropagation을 하지 않습니다. 
        with torch.no_grad():
            
            correct_test = 0

            for images, labels in valid_loader:

                # Move the training batch to the GPU
                images = images.to(device)
                labels = labels.to(device)

                # forward propagation
                outputs = model(images)

                # calculate the loss
                loss = criterion_(outputs, labels)
                valid_losses.append(loss.item())

            for images, labels in test_loader:
                # Move the training batch to the GPU
                images = images.to(device)
                labels = labels.to(device)

                # forward propagation
                outputs = model(images)

                # calculate the loss
                loss = criterion_(outputs, labels)
                test_losses.append(loss.item())

                # Check Accuracy
                # preds 는 output 중에서 가장 높은 값의 index를 가집니다. 
                _, preds = torch.max(outputs, 1)

                # label이 현재 one hot encoding 형태로 되어있기에 preds를 index로 받아 1인지 확인합니다. 
                # ex) 숫자 2 : label = [0,0,1,0,0,...,0] , label[i][preds] == 1 -> 정답
                for i in range(len(preds)):
                  if labels[i][preds[i]] == 1:
                    correct_test +=1
        
        # 원하는 Epoch마다 결과 출력 
        if (epoch) % 1== 0 :
            curr_time = round(time.time()-start_time)
            train_rec = round(train_losses[-1],5)
            valid_rec = round(valid_losses[-1],5)
            test_rec = round(test_losses[-1],5)
            test_acc = round(100*(correct_test)/len(labels),3)
            print('Epoch', epoch, ' / ',num_epochs)
            print(f"\t [Train loss : {train_rec}]  [Validation loss : {valid_rec}] [Test loss : {test_rec}], [Test Accuracy : {test_acc}%],[curr LR = {scheduler_.get_last_lr()}],[elapsed_time = {curr_time}sec] ")

        # Learning rate Scheduling
        # Scheduler에 따라 learning rate를 조절합니다. 
        scheduler_.step()
        
      
    print(f"\nTrain Ended, total_elapsed_time = {round(time.time()-start_time)} ")
    print("--------------------------------------------------------------------")
    
    # Loss 값 반환
    return train_losses, valid_losses, test_losses

# %% [markdown]
# ### Model Train

# %%
model = SimpleMLP()
model.to(device)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.1)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=2000, gamma=0.5)
train_losses, valid_losses, test_losses = train(model, criterion_ = criterion, optimizer_ = optimizer, scheduler_ = scheduler, num_epochs=10000)
# Out:
# ----------------------------------------------------------------------------
# /usr/local/lib/python3.8/dist-packages/torch/nn/functional.py:1956: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 	 [Train loss : 0.00036]  [Validation loss : 0.00034] [Test loss : 0.00034], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1249sec]
# Epoch 7503  /  10000
# 	 [Train loss : 0.00032]  [Validation loss : 0.00028] [Test loss : 0.0003], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1249sec]
# Epoch 7504  /  10000
# 	 [Train loss : 0.00027]  [Validation loss : 0.00026] [Test loss : 0.00026], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1249sec]
# Epoch 7505  /  10000
# 	 [Train loss : 0.00024]  [Validation loss : 0.00026] [Test loss : 0.00026], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1249sec]
# Epoch 7506  /  10000
# 	 [Train loss : 0.00023]  [Validation loss : 0.00025] [Test loss : 0.00027], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1249sec]
# Epoch 7507  /  10000
# 	 [Train loss : 0.00024]  [Validation loss : 0.00031] [Test loss : 0.00031], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1249sec]
# Epoch 7508  /  10000
# 	 [Train loss : 0.00026]  [Validation loss : 0.00032] [Test loss : 0.00034], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1250sec]
# Epoch 7509  /  10000
# 	 [Train loss : 0.0003]  [Validation loss : 0.00043] [Test loss : 0.00041], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1250sec]
# Epoch 7510  /  10000
# 	 [Train loss : 0.00034]  [Validation loss : 0.00045] [Test loss : 0.00047], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1250sec]
# Epoch 7511  /  10000
# 	 [Train loss : 0.00039]  [Validation loss : 0.00062] [Test loss : 0.00058], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1250sec]
# Epoch 7512  /  10000
# 	 [Train loss : 0.00044]  [Validation loss : 0.00071] [Test loss : 0.00073], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1250sec]
# Epoch 7513  /  10000
# 	 [Train loss : 0.00052]  [Validation loss : 0.00091] [Test loss : 0.00088], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1250sec]
# Epoch 7514  /  10000
# 	 [Train loss : 0.00061]  [Validation loss : 0.00126] [Test loss : 0.0013], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1251sec]
# Epoch 7515  /  10000
# 	 [Train loss : 0.00078]  [Validation loss : 0.0013] [Test loss : 0.00129], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1251sec]
# Epoch 7516  /  10000
# 	 [Train loss : 0.00089]  [Validation loss : 0.00188] [Test loss : 0.00195], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1251sec]
# Epoch 7517  /  10000
# 	 [Train loss : 0.00109]  [Validation loss : 0.00127] [Test loss : 0.0013], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1251sec]
# Epoch 7518  /  10000
# 	 [Train loss : 0.001]  [Validation loss : 0.00144] [Test loss : 0.00152], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1251sec]
# Epoch 7519  /  10000
# 	 [Train loss : 0.00088]  [Validation loss : 0.00058] [Test loss : 0.0006], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1251sec]
# Epoch 7520  /  10000
# 	 [Train loss : 0.00057]  [Validation loss : 0.00043] [Test loss : 0.00046], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1251sec]
# Epoch 7521  /  10000
# 	 [Train loss : 0.00035]  [Validation loss : 0.00035] [Test loss : 0.00036], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1252sec]
# Epoch 7522  /  10000
# 	 [Train loss : 0.00029]  [Validation loss : 0.00055] [Test loss : 0.00056], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1252sec]
# Epoch 7523  /  10000
# 	 [Train loss : 0.00037]  [Validation loss : 0.00072] [Test loss : 0.00077], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1252sec]
# Epoch 7524  /  10000
# 	 [Train loss : 0.00052]  [Validation loss : 0.00079] [Test loss : 0.00082], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1252sec]
# Epoch 7525  /  10000
# 	 [Train loss : 0.00058]  [Validation loss : 0.00077] [Test loss : 0.00083], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1252sec]
# Epoch 7526  /  10000
# 	 [Train loss : 0.0006]  [Validation loss : 0.00057] [Test loss : 0.00058], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1252sec]
# Epoch 7527  /  10000
# 	 [Train loss : 0.00049]  [Validation loss : 0.00047] [Test loss : 0.0005], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1253sec]
# Epoch 7528  /  10000
# 	 [Train loss : 0.00038]  [Validation loss : 0.00033] [Test loss : 0.00033], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1253sec]
# Epoch 7529  /  10000
# 	 [Train loss : 0.00031]  [Validation loss : 0.00044] [Test loss : 0.00046], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1253sec]
# Epoch 7530  /  10000
# 	 [Train loss : 0.00031]  [Validation loss : 0.00035] [Test loss : 0.00038], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1253sec]
# Epoch 7531  /  10000
# 	 [Train loss : 0.00033]  [Validation loss : 0.00047] [Test loss : 0.00048], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1253sec]
# Epoch 7532  /  10000
# 	 [Train loss : 0.00034]  [Validation loss : 0.00044] [Test loss : 0.00047], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1253sec]
# Epoch 7533  /  10000
# 	 [Train loss : 0.00034]  [Validation loss : 0.00035] [Test loss : 0.00034], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1254sec]
# Epoch 7534  /  10000
# 	 [Train loss : 0.00032]  [Validation loss : 0.00045] [Test loss : 0.00048], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1254sec]
# Epoch 7535  /  10000
# 	 [Train loss : 0.00032]  [Validation loss : 0.00031] [Test loss : 0.00031], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1254sec]
# Epoch 7536  /  10000
# 	 [Train loss : 0.00032]  [Validation loss : 0.00044] [Test loss : 0.00046], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1254sec]
# Epoch 7537  /  10000
# 	 [Train loss : 0.00033]  [Validation loss : 0.00032] [Test loss : 0.00031], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1254sec]
# Epoch 7538  /  10000
# 	 [Train loss : 0.00031]  [Validation loss : 0.00033] [Test loss : 0.00035], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1254sec]
# Epoch 7539  /  10000
# 	 [Train loss : 0.00027]  [Validation loss : 0.00028] [Test loss : 0.00029], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1255sec]
# Epoch 7540  /  10000
# 	 [Train loss : 0.00024]  [Validation loss : 0.00024] [Test loss : 0.00025], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1255sec]
# Epoch 7541  /  10000
# 	 [Train loss : 0.00023]  [Validation loss : 0.0003] [Test loss : 0.00032], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1255sec]
# Epoch 7542  /  10000
# 	 [Train loss : 0.00024]  [Validation loss : 0.00027] [Test loss : 0.00027], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1255sec]
# Epoch 7543  /  10000
# 	 [Train loss : 0.00027]  [Validation loss : 0.00034] [Test loss : 0.00035], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1255sec]
# Epoch 7544  /  10000
# 	 [Train loss : 0.00028]  [Validation loss : 0.0003] [Test loss : 0.00029], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1255sec]
# Epoch 7545  /  10000
# 	 [Train loss : 0.00028]  [Validation loss : 0.0003] [Test loss : 0.00032], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1256sec]
# Epoch 7546  /  10000
# 	 [Train loss : 0.00027]  [Validation loss : 0.00028] [Test loss : 0.00028], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1256sec]
# Epoch 7547  /  10000
# 	 [Train loss : 0.00025]  [Validation loss : 0.00027] [Test loss : 0.00028], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1256sec]
# Epoch 7548  /  10000
# 	 [Train loss : 0.00024]  [Validation loss : 0.00027] [Test loss : 0.00028], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1256sec]
# Epoch 7549  /  10000
# 	 [Train loss : 0.00024]  [Validation loss : 0.00027] [Test loss : 0.00028], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1256sec]
# Epoch 7550  /  10000
# 	 [Train loss : 0.00025]  [Validation loss : 0.00028] [Test loss : 0.00029], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1256sec]
# Epoch 7551  /  10000
# 	 [Train loss : 0.00025]  [Validation loss : 0.00026] [Test loss : 0.00027], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1257sec]
# Epoch 7552  /  10000
# 	 [Train loss : 0.00024]  [Validation loss : 0.00026] [Test loss : 0.00026], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1257sec]
# Epoch 7553  /  10000
# 	 [Train loss : 0.00023]  [Validation loss : 0.00024] [Test loss : 0.00024], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1257sec]
# Epoch 7554  /  10000
# 	 [Train loss : 0.00022]  [Validation loss : 0.00024] [Test loss : 0.00024], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1257sec]
# Epoch 7555  /  10000
# 	 [Train loss : 0.00022]  [Validation loss : 0.00024] [Test loss : 0.00024], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1257sec]
# Epoch 7556  /  10000
# 	 [Train loss : 0.00022]  [Validation loss : 0.00025] [Test loss : 0.00026], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1258sec]
# Epoch 7557  /  10000
# 	 [Train loss : 0.00023]  [Validation loss : 0.00025] [Test loss : 0.00026], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1258sec]
# Epoch 7558  /  10000
# 	 [Train loss : 0.00023]  [Validation loss : 0.00026] [Test loss : 0.00027], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1258sec]
# Epoch 7559  /  10000
# 	 [Train loss : 0.00023]  [Validation loss : 0.00025] [Test loss : 0.00026], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1258sec]
# Epoch 7560  /  10000
# 	 [Train loss : 0.00023]  [Validation loss : 0.00026] [Test loss : 0.00027], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1258sec]
# Epoch 7561  /  10000
# 	 [Train loss : 0.00023]  [Validation loss : 0.00025] [Test loss : 0.00025], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1258sec]
# Epoch 7562  /  10000
# 	 [Train loss : 0.00023]  [Validation loss : 0.00026] [Test loss : 0.00028], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1258sec]
# Epoch 7563  /  10000
# 	 [Train loss : 0.00023]  [Validation loss : 0.00025] [Test loss : 0.00025], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1259sec]
# Epoch 7564  /  10000
# 	 [Train loss : 0.00023]  [Validation loss : 0.00028] [Test loss : 0.00029], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1259sec]
# Epoch 7565  /  10000
# 	 [Train loss : 0.00024]  [Validation loss : 0.00027] [Test loss : 0.00026], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1259sec]
# Epoch 7566  /  10000
# 	 [Train loss : 0.00024]  [Validation loss : 0.00029] [Test loss : 0.00031], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1259sec]
# Epoch 7567  /  10000
# 	 [Train loss : 0.00025]  [Validation loss : 0.00028] [Test loss : 0.00027], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1259sec]
# Epoch 7568  /  10000
# 	 [Train loss : 0.00025]  [Validation loss : 0.00031] [Test loss : 0.00033], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1259sec]
# Epoch 7569  /  10000
# 	 [Train loss : 0.00026]  [Validation loss : 0.0003] [Test loss : 0.00029], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1260sec]
# Epoch 7570  /  10000
# 	 [Train loss : 0.00026]  [Validation loss : 0.00035] [Test loss : 0.00036], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1260sec]
# Epoch 7571  /  10000
# 	 [Train loss : 0.00028]  [Validation loss : 0.00034] [Test loss : 0.00033], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1260sec]
# Epoch 7572  /  10000
# 	 [Train loss : 0.00029]  [Validation loss : 0.00042] [Test loss : 0.00044], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1260sec]
# Epoch 7573  /  10000
# 	 [Train loss : 0.00031]  [Validation loss : 0.00042] [Test loss : 0.00041], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1260sec]
# Epoch 7574  /  10000
# 	 [Train loss : 0.00034]  [Validation loss : 0.00055] [Test loss : 0.00057], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1260sec]
# Epoch 7575  /  10000
# 	 [Train loss : 0.00038]  [Validation loss : 0.00053] [Test loss : 0.00051], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1261sec]
# Epoch 7576  /  10000
# 	 [Train loss : 0.00041]  [Validation loss : 0.00071] [Test loss : 0.00074], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1261sec]
# Epoch 7577  /  10000
# 	 [Train loss : 0.00046]  [Validation loss : 0.00063] [Test loss : 0.00061], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1261sec]
# Epoch 7578  /  10000
# 	 [Train loss : 0.00048]  [Validation loss : 0.00082] [Test loss : 0.00085], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1261sec]
# Epoch 7579  /  10000
# 	 [Train loss : 0.00051]  [Validation loss : 0.00063] [Test loss : 0.00061], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1261sec]
# Epoch 7580  /  10000
# 	 [Train loss : 0.00049]  [Validation loss : 0.00073] [Test loss : 0.00075], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1261sec]
# Epoch 7581  /  10000
# 	 [Train loss : 0.00048]  [Validation loss : 0.00049] [Test loss : 0.00047], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1262sec]
# Epoch 7582  /  10000
# 	 [Train loss : 0.00042]  [Validation loss : 0.00047] [Test loss : 0.0005], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1262sec]
# Epoch 7583  /  10000
# 	 [Train loss : 0.00036]  [Validation loss : 0.00032] [Test loss : 0.00031], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1262sec]
# Epoch 7584  /  10000
# 	 [Train loss : 0.0003]  [Validation loss : 0.00031] [Test loss : 0.00034], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1262sec]
# Epoch 7585  /  10000
# 	 [Train loss : 0.00027]  [Validation loss : 0.00024] [Test loss : 0.00025], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1262sec]
# Epoch 7586  /  10000
# 	 [Train loss : 0.00024]  [Validation loss : 0.00029] [Test loss : 0.0003], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1262sec]
# Epoch 7587  /  10000
# 	 [Train loss : 0.00023]  [Validation loss : 0.00025] [Test loss : 0.00027], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1263sec]
# Epoch 7588  /  10000
# 	 [Train loss : 0.00024]  [Validation loss : 0.00031] [Test loss : 0.00031], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1263sec]
# Epoch 7589  /  10000
# 	 [Train loss : 0.00025]  [Validation loss : 0.00031] [Test loss : 0.00033], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1263sec]
# Epoch 7590  /  10000
# 	 [Train loss : 0.00027]  [Validation loss : 0.00036] [Test loss : 0.00035], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1263sec]
# Epoch 7591  /  10000
# 	 [Train loss : 0.0003]  [Validation loss : 0.00036] [Test loss : 0.00039], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1263sec]
# Epoch 7592  /  10000
# 	 [Train loss : 0.00032]  [Validation loss : 0.0004] [Test loss : 0.00039], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1263sec]
# Epoch 7593  /  10000
# 	 [Train loss : 0.00033]  [Validation loss : 0.0004] [Test loss : 0.00043], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1264sec]
# Epoch 7594  /  10000
# 	 [Train loss : 0.00034]  [Validation loss : 0.0004] [Test loss : 0.00039], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1264sec]
# Epoch 7595  /  10000
# 	 [Train loss : 0.00033]  [Validation loss : 0.0004] [Test loss : 0.00043], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1264sec]
# Epoch 7596  /  10000
# 	 [Train loss : 0.00033]  [Validation loss : 0.00038] [Test loss : 0.00037], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1264sec]
# Epoch 7597  /  10000
# 	 [Train loss : 0.00031]  [Validation loss : 0.00038] [Test loss : 0.0004], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1264sec]
# Epoch 7598  /  10000
# 	 [Train loss : 0.00031]  [Validation loss : 0.00036] [Test loss : 0.00035], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1264sec]
# Epoch 7599  /  10000
# 	 [Train loss : 0.00029]  [Validation loss : 0.00034] [Test loss : 0.00036], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1265sec]
# Epoch 7600  /  10000
# 	 [Train loss : 0.00028]  [Validation loss : 0.00032] [Test loss : 0.00032], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1265sec]
# Epoch 7601  /  10000
# 	 [Train loss : 0.00027]  [Validation loss : 0.00029] [Test loss : 0.00031], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1265sec]
# Epoch 7602  /  10000
# 	 [Train loss : 0.00025]  [Validation loss : 0.00028] [Test loss : 0.00028], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1265sec]
# Epoch 7603  /  10000
# 	 [Train loss : 0.00024]  [Validation loss : 0.00025] [Test loss : 0.00026], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1265sec]
# Epoch 7604  /  10000
# 	 [Train loss : 0.00023]  [Validation loss : 0.00025] [Test loss : 0.00025], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1265sec]
# Epoch 7605  /  10000
# 	 [Train loss : 0.00022]  [Validation loss : 0.00024] [Test loss : 0.00025], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1266sec]
# Epoch 7606  /  10000
# 	 [Train loss : 0.00022]  [Validation loss : 0.00024] [Test loss : 0.00024], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1266sec]
# Epoch 7607  /  10000
# 	 [Train loss : 0.00022]  [Validation loss : 0.00024] [Test loss : 0.00024], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1266sec]
# Epoch 7608  /  10000
# 	 [Train loss : 0.00022]  [Validation loss : 0.00023] [Test loss : 0.00024], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1266sec]
# Epoch 7609  /  10000
# 	 [Train loss : 0.00022]  [Validation loss : 0.00024] [Test loss : 0.00024], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1266sec]
# Epoch 7610  /  10000
# 	 [Train loss : 0.00022]  [Validation loss : 0.00023] [Test loss : 0.00025], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1266sec]
# Epoch 7611  /  10000
# 	 [Train loss : 0.00022]  [Validation loss : 0.00024] [Test loss : 0.00024], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1267sec]
# Epoch 7612  /  10000
# 	 [Train loss : 0.00022]  [Validation loss : 0.00024] [Test loss : 0.00025], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1267sec]
# Epoch 7613  /  10000
# 	 [Train loss : 0.00022]  [Validation loss : 0.00025] [Test loss : 0.00025], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1267sec]
# Epoch 7614  /  10000
# 	 [Train loss : 0.00023]  [Validation loss : 0.00025] [Test loss : 0.00027], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1267sec]
# Epoch 7615  /  10000
# 	 [Train loss : 0.00023]  [Validation loss : 0.00026] [Test loss : 0.00026], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1267sec]
# Epoch 7616  /  10000
# 	 [Train loss : 0.00024]  [Validation loss : 0.00027] [Test loss : 0.00029], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1267sec]
# Epoch 7617  /  10000
# 	 [Train loss : 0.00024]  [Validation loss : 0.00029] [Test loss : 0.00029], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1268sec]
# Epoch 7618  /  10000
# 	 [Train loss : 0.00025]  [Validation loss : 0.00032] [Test loss : 0.00034], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1268sec]
# Epoch 7619  /  10000
# 	 [Train loss : 0.00027]  [Validation loss : 0.00036] [Test loss : 0.00035], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1268sec]
# Epoch 7620  /  10000
# 	 [Train loss : 0.00029]  [Validation loss : 0.00042] [Test loss : 0.00044], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1268sec]
# Epoch 7621  /  10000
# 	 [Train loss : 0.00033]  [Validation loss : 0.00049] [Test loss : 0.00047], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1268sec]
# Epoch 7622  /  10000
# 	 [Train loss : 0.00037]  [Validation loss : 0.00064] [Test loss : 0.00067], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1268sec]
# Epoch 7623  /  10000
# 	 [Train loss : 0.00044]  [Validation loss : 0.00072] [Test loss : 0.0007], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1269sec]
# Epoch 7624  /  10000
# 	 [Train loss : 0.00052]  [Validation loss : 0.00102] [Test loss : 0.00106], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1269sec]
# Epoch 7625  /  10000
# 	 [Train loss : 0.00064]  [Validation loss : 0.001] [Test loss : 0.00098], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1269sec]
# Epoch 7626  /  10000
# 	 [Train loss : 0.00071]  [Validation loss : 0.00137] [Test loss : 0.00141], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1269sec]
# Epoch 7627  /  10000
# 	 [Train loss : 0.00081]  [Validation loss : 0.001] [Test loss : 0.00099], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1269sec]
# Epoch 7628  /  10000
# 	 [Train loss : 0.00077]  [Validation loss : 0.00113] [Test loss : 0.00118], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1269sec]
# Epoch 7629  /  10000
# 	 [Train loss : 0.00072]  [Validation loss : 0.00064] [Test loss : 0.00064], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1270sec]
# Epoch 7630  /  10000
# 	 [Train loss : 0.00058]  [Validation loss : 0.00059] [Test loss : 0.00063], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1270sec]
# Epoch 7631  /  10000
# 	 [Train loss : 0.00047]  [Validation loss : 0.00037] [Test loss : 0.00038], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1270sec]
# Epoch 7632  /  10000
# 	 [Train loss : 0.00039]  [Validation loss : 0.00055] [Test loss : 0.00057], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1270sec]
# Epoch 7633  /  10000
# 	 [Train loss : 0.00035]  [Validation loss : 0.00035] [Test loss : 0.00037], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1270sec]
# Epoch 7634  /  10000
# 	 [Train loss : 0.00033]  [Validation loss : 0.00055] [Test loss : 0.00056], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1270sec]
# Epoch 7635  /  10000
# 	 [Train loss : 0.00032]  [Validation loss : 0.00039] [Test loss : 0.00042], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1271sec]
# Epoch 7636  /  10000
# 	 [Train loss : 0.00033]  [Validation loss : 0.00044] [Test loss : 0.00045], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1271sec]
# Epoch 7637  /  10000
# 	 [Train loss : 0.00035]  [Validation loss : 0.00044] [Test loss : 0.00047], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1271sec]
# Epoch 7638  /  10000
# 	 [Train loss : 0.00038]  [Validation loss : 0.00043] [Test loss : 0.00044], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1271sec]
# Epoch 7639  /  10000
# 	 [Train loss : 0.00041]  [Validation loss : 0.00048] [Test loss : 0.00052], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1271sec]
# Epoch 7640  /  10000
# 	 [Train loss : 0.00041]  [Validation loss : 0.00036] [Test loss : 0.00037], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1271sec]
# Epoch 7641  /  10000
# 	 [Train loss : 0.00038]  [Validation loss : 0.00044] [Test loss : 0.00047], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1272sec]
# Epoch 7642  /  10000
# 	 [Train loss : 0.00032]  [Validation loss : 0.00026] [Test loss : 0.00026], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1272sec]
# Epoch 7643  /  10000
# 	 [Train loss : 0.00027]  [Validation loss : 0.00032] [Test loss : 0.00034], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1272sec]
# Epoch 7644  /  10000
# 	 [Train loss : 0.00024]  [Validation loss : 0.00024] [Test loss : 0.00025], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1272sec]
# Epoch 7645  /  10000
# 	 [Train loss : 0.00023]  [Validation loss : 0.00028] [Test loss : 0.00029], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1272sec]
# Epoch 7646  /  10000
# 	 [Train loss : 0.00025]  [Validation loss : 0.00032] [Test loss : 0.00033], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1272sec]
# Epoch 7647  /  10000
# 	 [Train loss : 0.00028]  [Validation loss : 0.00031] [Test loss : 0.00032], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1273sec]
# Epoch 7648  /  10000
# 	 [Train loss : 0.0003]  [Validation loss : 0.00036] [Test loss : 0.00037], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1273sec]
# Epoch 7649  /  10000
# 	 [Train loss : 0.00031]  [Validation loss : 0.00031] [Test loss : 0.00032], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1273sec]
# Epoch 7650  /  10000
# 	 [Train loss : 0.0003]  [Validation loss : 0.00031] [Test loss : 0.00033], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1273sec]
# Epoch 7651  /  10000
# 	 [Train loss : 0.00028]  [Validation loss : 0.00027] [Test loss : 0.00028], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1273sec]
# Epoch 7652  /  10000
# 	 [Train loss : 0.00026]  [Validation loss : 0.00026] [Test loss : 0.00027], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1273sec]
# Epoch 7653  /  10000
# 	 [Train loss : 0.00024]  [Validation loss : 0.00027] [Test loss : 0.00027], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1274sec]
# Epoch 7654  /  10000
# 	 [Train loss : 0.00023]  [Validation loss : 0.00025] [Test loss : 0.00025], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1274sec]
# Epoch 7655  /  10000
# 	 [Train loss : 0.00023]  [Validation loss : 0.00028] [Test loss : 0.00028], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1274sec]
# Epoch 7656  /  10000
# 	 [Train loss : 0.00023]  [Validation loss : 0.00025] [Test loss : 0.00026], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1274sec]
# Epoch 7657  /  10000
# 	 [Train loss : 0.00024]  [Validation loss : 0.00028] [Test loss : 0.00028], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1274sec]
# Epoch 7658  /  10000
# 	 [Train loss : 0.00024]  [Validation loss : 0.00024] [Test loss : 0.00025], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1274sec]
# Epoch 7659  /  10000
# 	 [Train loss : 0.00024]  [Validation loss : 0.00026] [Test loss : 0.00026], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1274sec]
# Epoch 7660  /  10000
# 	 [Train loss : 0.00023]  [Validation loss : 0.00024] [Test loss : 0.00025], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1275sec]
# Epoch 7661  /  10000
# 	 [Train loss : 0.00023]  [Validation loss : 0.00024] [Test loss : 0.00025], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1275sec]
# Epoch 7662  /  10000
# 	 [Train loss : 0.00023]  [Validation loss : 0.00025] [Test loss : 0.00026], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1275sec]
# Epoch 7663  /  10000
# 	 [Train loss : 0.00023]  [Validation loss : 0.00026] [Test loss : 0.00026], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1275sec]
# Epoch 7664  /  10000
# 	 [Train loss : 0.00023]  [Validation loss : 0.00026] [Test loss : 0.00027], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1275sec]
# Epoch 7665  /  10000
# 	 [Train loss : 0.00024]  [Validation loss : 0.00029] [Test loss : 0.00029], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1276sec]
# Epoch 7666  /  10000
# 	 [Train loss : 0.00025]  [Validation loss : 0.00027] [Test loss : 0.00028], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1276sec]
# Epoch 7667  /  10000
# 	 [Train loss : 0.00025]  [Validation loss : 0.0003] [Test loss : 0.0003], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1276sec]
# Epoch 7668  /  10000
# 	 [Train loss : 0.00026]  [Validation loss : 0.00028] [Test loss : 0.00029], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1276sec]
# Epoch 7669  /  10000
# 	 [Train loss : 0.00026]  [Validation loss : 0.0003] [Test loss : 0.0003], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1276sec]
# Epoch 7670  /  10000
# 	 [Train loss : 0.00026]  [Validation loss : 0.00028] [Test loss : 0.0003], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1276sec]
# Epoch 7671  /  10000
# 	 [Train loss : 0.00027]  [Validation loss : 0.00031] [Test loss : 0.00031], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1277sec]
# Epoch 7672  /  10000
# 	 [Train loss : 0.00028]  [Validation loss : 0.0003] [Test loss : 0.00032], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1277sec]
# Epoch 7673  /  10000
# 	 [Train loss : 0.00029]  [Validation loss : 0.00036] [Test loss : 0.00035], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1277sec]
# Epoch 7674  /  10000
# 	 [Train loss : 0.00031]  [Validation loss : 0.00035] [Test loss : 0.00038], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1277sec]
# Epoch 7675  /  10000
# 	 [Train loss : 0.00035]  [Validation loss : 0.00045] [Test loss : 0.00042], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1277sec]
# Epoch 7676  /  10000
# 	 [Train loss : 0.00038]  [Validation loss : 0.00046] [Test loss : 0.00048], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1277sec]
# Epoch 7677  /  10000
# 	 [Train loss : 0.00043]  [Validation loss : 0.00057] [Test loss : 0.00054], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1278sec]
# Epoch 7678  /  10000
# 	 [Train loss : 0.00048]  [Validation loss : 0.00059] [Test loss : 0.00062], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1278sec]
# Epoch 7679  /  10000
# 	 [Train loss : 0.00054]  [Validation loss : 0.0007] [Test loss : 0.00065], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1278sec]
# Epoch 7680  /  10000
# 	 [Train loss : 0.00058]  [Validation loss : 0.00071] [Test loss : 0.00074], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1278sec]
# Epoch 7681  /  10000
# 	 [Train loss : 0.00062]  [Validation loss : 0.00076] [Test loss : 0.00071], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1278sec]
# Epoch 7682  /  10000
# 	 [Train loss : 0.00062]  [Validation loss : 0.00075] [Test loss : 0.00079], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1278sec]
# Epoch 7683  /  10000
# 	 [Train loss : 0.00063]  [Validation loss : 0.00073] [Test loss : 0.0007], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1279sec]
# Epoch 7684  /  10000
# 	 [Train loss : 0.00062]  [Validation loss : 0.00074] [Test loss : 0.00079], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1279sec]
# Epoch 7685  /  10000
# 	 [Train loss : 0.00061]  [Validation loss : 0.00065] [Test loss : 0.00064], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1279sec]
# Epoch 7686  /  10000
# 	 [Train loss : 0.00058]  [Validation loss : 0.00067] [Test loss : 0.00072], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1279sec]
# Epoch 7687  /  10000
# 	 [Train loss : 0.00054]  [Validation loss : 0.00056] [Test loss : 0.00057], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1279sec]
# Epoch 7688  /  10000
# 	 [Train loss : 0.00049]  [Validation loss : 0.00051] [Test loss : 0.00055], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1279sec]
# Epoch 7689  /  10000
# 	 [Train loss : 0.00043]  [Validation loss : 0.00053] [Test loss : 0.00054], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1280sec]
# Epoch 7690  /  10000
# 	 [Train loss : 0.00038]  [Validation loss : 0.00042] [Test loss : 0.00045], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1280sec]
# Epoch 7691  /  10000
# 	 [Train loss : 0.00036]  [Validation loss : 0.00055] [Test loss : 0.00055], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1280sec]
# Epoch 7692  /  10000
# 	 [Train loss : 0.00035]  [Validation loss : 0.00044] [Test loss : 0.00045], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1280sec]
# Epoch 7693  /  10000
# 	 [Train loss : 0.00036]  [Validation loss : 0.00055] [Test loss : 0.00055], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1280sec]
# Epoch 7694  /  10000
# 	 [Train loss : 0.00035]  [Validation loss : 0.00039] [Test loss : 0.00039], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1280sec]
# Epoch 7695  /  10000
# 	 [Train loss : 0.00034]  [Validation loss : 0.00046] [Test loss : 0.00047], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1281sec]
# Epoch 7696  /  10000
# 	 [Train loss : 0.00031]  [Validation loss : 0.00027] [Test loss : 0.00027], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1281sec]
# Epoch 7697  /  10000
# 	 [Train loss : 0.00028]  [Validation loss : 0.00032] [Test loss : 0.00034], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1281sec]
# Epoch 7698  /  10000
# 	 [Train loss : 0.00025]  [Validation loss : 0.00025] [Test loss : 0.00025], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1281sec]
# Epoch 7699  /  10000
# 	 [Train loss : 0.00023]  [Validation loss : 0.00027] [Test loss : 0.00028], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1281sec]
# Epoch 7700  /  10000
# 	 [Train loss : 0.00024]  [Validation loss : 0.00034] [Test loss : 0.00033], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1281sec]
# Epoch 7701  /  10000
# 	 [Train loss : 0.00025]  [Validation loss : 0.00033] [Test loss : 0.00034], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1282sec]
# Epoch 7702  /  10000
# 	 [Train loss : 0.00028]  [Validation loss : 0.00045] [Test loss : 0.00044], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1282sec]
# Epoch 7703  /  10000
# 	 [Train loss : 0.0003]  [Validation loss : 0.00043] [Test loss : 0.00045], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1282sec]
# Epoch 7704  /  10000
# 	 [Train loss : 0.00033]  [Validation loss : 0.00049] [Test loss : 0.00048], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1282sec]
# Epoch 7705  /  10000
# 	 [Train loss : 0.00033]  [Validation loss : 0.00049] [Test loss : 0.0005], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1282sec]
# Epoch 7706  /  10000
# 	 [Train loss : 0.00034]  [Validation loss : 0.00045] [Test loss : 0.00045], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1282sec]
# Epoch 7707  /  10000
# 	 [Train loss : 0.00033]  [Validation loss : 0.00046] [Test loss : 0.00047], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1283sec]
# Epoch 7708  /  10000
# 	 [Train loss : 0.00033]  [Validation loss : 0.00037] [Test loss : 0.00037], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1283sec]
# Epoch 7709  /  10000
# 	 [Train loss : 0.00031]  [Validation loss : 0.00038] [Test loss : 0.0004], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1283sec]
# Epoch 7710  /  10000
# 	 [Train loss : 0.00029]  [Validation loss : 0.0003] [Test loss : 0.0003], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1283sec]
# Epoch 7711  /  10000
# 	 [Train loss : 0.00027]  [Validation loss : 0.00031] [Test loss : 0.00033], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1283sec]
# Epoch 7712  /  10000
# 	 [Train loss : 0.00026]  [Validation loss : 0.00026] [Test loss : 0.00026], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1283sec]
# Epoch 7713  /  10000
# 	 [Train loss : 0.00025]  [Validation loss : 0.00028] [Test loss : 0.00029], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1283sec]
# Epoch 7714  /  10000
# 	 [Train loss : 0.00024]  [Validation loss : 0.00025] [Test loss : 0.00025], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1284sec]
# Epoch 7715  /  10000
# 	 [Train loss : 0.00024]  [Validation loss : 0.00026] [Test loss : 0.00027], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1284sec]
# Epoch 7716  /  10000
# 	 [Train loss : 0.00023]  [Validation loss : 0.00025] [Test loss : 0.00025], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1284sec]
# Epoch 7717  /  10000
# 	 [Train loss : 0.00023]  [Validation loss : 0.00025] [Test loss : 0.00026], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1284sec]
# Epoch 7718  /  10000
# 	 [Train loss : 0.00023]  [Validation loss : 0.00025] [Test loss : 0.00025], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1284sec]
# Epoch 7719  /  10000
# 	 [Train loss : 0.00024]  [Validation loss : 0.00025] [Test loss : 0.00026], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1284sec]
# Epoch 7720  /  10000
# 	 [Train loss : 0.00024]  [Validation loss : 0.00025] [Test loss : 0.00025], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1285sec]
# Epoch 7721  /  10000
# 	 [Train loss : 0.00024]  [Validation loss : 0.00025] [Test loss : 0.00026], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1285sec]
# Epoch 7722  /  10000
# 	 [Train loss : 0.00023]  [Validation loss : 0.00025] [Test loss : 0.00025], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1285sec]
# Epoch 7723  /  10000
# 	 [Train loss : 0.00023]  [Validation loss : 0.00024] [Test loss : 0.00025], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1285sec]
# Epoch 7724  /  10000
# 	 [Train loss : 0.00023]  [Validation loss : 0.00024] [Test loss : 0.00024], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1285sec]
# Epoch 7725  /  10000
# 	 [Train loss : 0.00022]  [Validation loss : 0.00023] [Test loss : 0.00024], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1285sec]
# Epoch 7726  /  10000
# 	 [Train loss : 0.00022]  [Validation loss : 0.00023] [Test loss : 0.00023], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1286sec]
# Epoch 7727  /  10000
# 	 [Train loss : 0.00022]  [Validation loss : 0.00023] [Test loss : 0.00024], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1286sec]
# Epoch 7728  /  10000
# 	 [Train loss : 0.00021]  [Validation loss : 0.00023] [Test loss : 0.00023], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1286sec]
# Epoch 7729  /  10000
# 	 [Train loss : 0.00021]  [Validation loss : 0.00023] [Test loss : 0.00023], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1286sec]
# Epoch 7730  /  10000
# 	 [Train loss : 0.00021]  [Validation loss : 0.00023] [Test loss : 0.00023], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1286sec]
# Epoch 7731  /  10000
# 	 [Train loss : 0.00021]  [Validation loss : 0.00023] [Test loss : 0.00023], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1286sec]
# Epoch 7732  /  10000
# 	 [Train loss : 0.00021]  [Validation loss : 0.00023] [Test loss : 0.00023], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1287sec]
# Epoch 7733  /  10000
# 	 [Train loss : 0.00021]  [Validation loss : 0.00023] [Test loss : 0.00023], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1287sec]
# Epoch 7734  /  10000
# 	 [Train loss : 0.00021]  [Validation loss : 0.00023] [Test loss : 0.00023], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1287sec]
# Epoch 7735  /  10000
# 	 [Train loss : 0.00021]  [Validation loss : 0.00023] [Test loss : 0.00023], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1287sec]
# Epoch 7736  /  10000
# 	 [Train loss : 0.00021]  [Validation loss : 0.00023] [Test loss : 0.00024], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1287sec]
# Epoch 7737  /  10000
# 	 [Train loss : 0.00021]  [Validation loss : 0.00024] [Test loss : 0.00024], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1287sec]
# Epoch 7738  /  10000
# 	 [Train loss : 0.00022]  [Validation loss : 0.00025] [Test loss : 0.00026], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1288sec]
# Epoch 7739  /  10000
# 	 [Train loss : 0.00022]  [Validation loss : 0.00027] [Test loss : 0.00026], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1288sec]
# Epoch 7740  /  10000
# 	 [Train loss : 0.00024]  [Validation loss : 0.0003] [Test loss : 0.00032], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1288sec]
# Epoch 7741  /  10000
# 	 [Train loss : 0.00026]  [Validation loss : 0.00036] [Test loss : 0.00035], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1288sec]
# Epoch 7742  /  10000
# 	 [Train loss : 0.00029]  [Validation loss : 0.00048] [Test loss : 0.00051], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1288sec]
# Epoch 7743  /  10000
# 	 [Train loss : 0.00036]  [Validation loss : 0.00064] [Test loss : 0.00061], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1288sec]
# Epoch 7744  /  10000
# 	 [Train loss : 0.00046]  [Validation loss : 0.00105] [Test loss : 0.00108], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1289sec]
# Epoch 7745  /  10000
# 	 [Train loss : 0.00065]  [Validation loss : 0.00133] [Test loss : 0.00128], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1289sec]
# Epoch 7746  /  10000
# 	 [Train loss : 0.00089]  [Validation loss : 0.00238] [Test loss : 0.00241], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1289sec]
# Epoch 7747  /  10000
# 	 [Train loss : 0.00131]  [Validation loss : 0.00215] [Test loss : 0.00211], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1289sec]
# Epoch 7748  /  10000
# 	 [Train loss : 0.00149]  [Validation loss : 0.00302] [Test loss : 0.00308], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1289sec]
# Epoch 7749  /  10000
# 	 [Train loss : 0.00165]  [Validation loss : 0.0016] [Test loss : 0.00161], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1289sec]
# Epoch 7750  /  10000
# 	 [Train loss : 0.00127]  [Validation loss : 0.00116] [Test loss : 0.00124], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1290sec]
# Epoch 7751  /  10000
# 	 [Train loss : 0.00096]  [Validation loss : 0.00113] [Test loss : 0.00114], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1290sec]
# Epoch 7752  /  10000
# 	 [Train loss : 0.00092]  [Validation loss : 0.0018] [Test loss : 0.0018], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1290sec]
# Epoch 7753  /  10000
# 	 [Train loss : 0.00104]  [Validation loss : 0.00118] [Test loss : 0.00121], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1290sec]
# Epoch 7754  /  10000
# 	 [Train loss : 0.00103]  [Validation loss : 0.00185] [Test loss : 0.00185], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1290sec]
# Epoch 7755  /  10000
# 	 [Train loss : 0.00076]  [Validation loss : 0.00055] [Test loss : 0.00057], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1290sec]
# Epoch 7756  /  10000
# 	 [Train loss : 0.00057]  [Validation loss : 0.00064] [Test loss : 0.00069], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1291sec]
# Epoch 7757  /  10000
# 	 [Train loss : 0.00053]  [Validation loss : 0.00078] [Test loss : 0.00078], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1291sec]
# Epoch 7758  /  10000
# 	 [Train loss : 0.00058]  [Validation loss : 0.00054] [Test loss : 0.00056], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1291sec]
# Epoch 7759  /  10000
# 	 [Train loss : 0.00052]  [Validation loss : 0.00061] [Test loss : 0.00062], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1291sec]
# Epoch 7760  /  10000
# 	 [Train loss : 0.00037]  [Validation loss : 0.00035] [Test loss : 0.00035], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1291sec]
# Epoch 7761  /  10000
# 	 [Train loss : 0.00035]  [Validation loss : 0.00066] [Test loss : 0.00069], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1291sec]
# Epoch 7762  /  10000
# 	 [Train loss : 0.00049]  [Validation loss : 0.00076] [Test loss : 0.00074], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1292sec]
# Epoch 7763  /  10000
# 	 [Train loss : 0.00061]  [Validation loss : 0.00074] [Test loss : 0.00077], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1292sec]
# Epoch 7764  /  10000
# 	 [Train loss : 0.00056]  [Validation loss : 0.00047] [Test loss : 0.00046], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1292sec]
# Epoch 7765  /  10000
# 	 [Train loss : 0.00038]  [Validation loss : 0.00045] [Test loss : 0.00047], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1292sec]
# Epoch 7766  /  10000
# 	 [Train loss : 0.00026]  [Validation loss : 0.00027] [Test loss : 0.00028], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1292sec]
# Epoch 7767  /  10000
# 	 [Train loss : 0.00028]  [Validation loss : 0.00055] [Test loss : 0.00055], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1292sec]
# Epoch 7768  /  10000
# 	 [Train loss : 0.00034]  [Validation loss : 0.00039] [Test loss : 0.00041], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1293sec]
# Epoch 7769  /  10000
# 	 [Train loss : 0.00035]  [Validation loss : 0.00034] [Test loss : 0.00034], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1293sec]
# Epoch 7770  /  10000
# 	 [Train loss : 0.00029]  [Validation loss : 0.00046] [Test loss : 0.00048], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1293sec]
# Epoch 7771  /  10000
# 	 [Train loss : 0.00027]  [Validation loss : 0.00026] [Test loss : 0.00027], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1293sec]
# Epoch 7772  /  10000
# 	 [Train loss : 0.0003]  [Validation loss : 0.00062] [Test loss : 0.00062], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1293sec]
# Epoch 7773  /  10000
# 	 [Train loss : 0.00033]  [Validation loss : 0.00029] [Test loss : 0.0003], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1293sec]
# Epoch 7774  /  10000
# 	 [Train loss : 0.00032]  [Validation loss : 0.00039] [Test loss : 0.0004], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1294sec]
# Epoch 7775  /  10000
# 	 [Train loss : 0.00026]  [Validation loss : 0.00027] [Test loss : 0.00027], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1294sec]
# Epoch 7776  /  10000
# 	 [Train loss : 0.00023]  [Validation loss : 0.00026] [Test loss : 0.00027], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1294sec]
# Epoch 7777  /  10000
# 	 [Train loss : 0.00024]  [Validation loss : 0.00039] [Test loss : 0.00039], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1294sec]
# Epoch 7778  /  10000
# 	 [Train loss : 0.00026]  [Validation loss : 0.00029] [Test loss : 0.0003], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1294sec]
# Epoch 7779  /  10000
# 	 [Train loss : 0.00027]  [Validation loss : 0.00035] [Test loss : 0.00035], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1294sec]
# Epoch 7780  /  10000
# 	 [Train loss : 0.00025]  [Validation loss : 0.00023] [Test loss : 0.00024], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1295sec]
# Epoch 7781  /  10000
# 	 [Train loss : 0.00023]  [Validation loss : 0.00027] [Test loss : 0.00028], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1295sec]
# Epoch 7782  /  10000
# 	 [Train loss : 0.00023]  [Validation loss : 0.00028] [Test loss : 0.00028], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1295sec]
# Epoch 7783  /  10000
# 	 [Train loss : 0.00024]  [Validation loss : 0.00029] [Test loss : 0.00031], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1295sec]
# Epoch 7784  /  10000
# 	 [Train loss : 0.00026]  [Validation loss : 0.00031] [Test loss : 0.0003], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1295sec]
# Epoch 7785  /  10000
# 	 [Train loss : 0.00025]  [Validation loss : 0.00028] [Test loss : 0.00029], [Test Accuracy : 0.0%],[curr LR = [0.0125]],[elapsed_time = 1295sec]
# Epoch 7786  /  10000
# ...
# Epoch 9907  /  10000
# 	 [Train loss : 0.00016]  [Validation loss : 0.00018] [Test loss : 0.00017], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1646sec]
# Epoch 9908  /  10000
# 	 [Train loss : 0.00016]  [Validation loss : 0.00018] [Test loss : 0.00019], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1646sec]
# Epoch 9909  /  10000
# 	 [Train loss : 0.00016]  [Validation loss : 0.00018] [Test loss : 0.00017], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1646sec]
# Epoch 9910  /  10000
# 	 [Train loss : 0.00016]  [Validation loss : 0.00017] [Test loss : 0.00018], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1646sec]
# Epoch 9911  /  10000
# 	 [Train loss : 0.00016]  [Validation loss : 0.00017] [Test loss : 0.00017], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1646sec]
# Epoch 9912  /  10000
# 	 [Train loss : 0.00015]  [Validation loss : 0.00016] [Test loss : 0.00017], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1646sec]
# Epoch 9913  /  10000
# 	 [Train loss : 0.00015]  [Validation loss : 0.00016] [Test loss : 0.00016], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1647sec]
# Epoch 9914  /  10000
# 	 [Train loss : 0.00015]  [Validation loss : 0.00016] [Test loss : 0.00016], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1647sec]
# Epoch 9915  /  10000
# 	 [Train loss : 0.00015]  [Validation loss : 0.00016] [Test loss : 0.00016], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1647sec]
# Epoch 9916  /  10000
# 	 [Train loss : 0.00015]  [Validation loss : 0.00016] [Test loss : 0.00016], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1647sec]
# Epoch 9917  /  10000
# 	 [Train loss : 0.00015]  [Validation loss : 0.00016] [Test loss : 0.00017], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1647sec]
# Epoch 9918  /  10000
# 	 [Train loss : 0.00015]  [Validation loss : 0.00017] [Test loss : 0.00017], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1647sec]
# Epoch 9919  /  10000
# 	 [Train loss : 0.00015]  [Validation loss : 0.00016] [Test loss : 0.00017], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1648sec]
# Epoch 9920  /  10000
# 	 [Train loss : 0.00015]  [Validation loss : 0.00017] [Test loss : 0.00017], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1648sec]
# Epoch 9921  /  10000
# 	 [Train loss : 0.00015]  [Validation loss : 0.00016] [Test loss : 0.00017], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1648sec]
# Epoch 9922  /  10000
# 	 [Train loss : 0.00015]  [Validation loss : 0.00016] [Test loss : 0.00017], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1648sec]
# Epoch 9923  /  10000
# 	 [Train loss : 0.00015]  [Validation loss : 0.00017] [Test loss : 0.00017], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1648sec]
# Epoch 9924  /  10000
# 	 [Train loss : 0.00015]  [Validation loss : 0.00017] [Test loss : 0.00017], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1648sec]
# Epoch 9925  /  10000
# 	 [Train loss : 0.00015]  [Validation loss : 0.00017] [Test loss : 0.00017], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1648sec]
# Epoch 9926  /  10000
# 	 [Train loss : 0.00016]  [Validation loss : 0.00018] [Test loss : 0.00019], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1649sec]
# Epoch 9927  /  10000
# 	 [Train loss : 0.00016]  [Validation loss : 0.0002] [Test loss : 0.0002], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1649sec]
# Epoch 9928  /  10000
# 	 [Train loss : 0.00017]  [Validation loss : 0.00022] [Test loss : 0.00023], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1649sec]
# Epoch 9929  /  10000
# 	 [Train loss : 0.00018]  [Validation loss : 0.00025] [Test loss : 0.00025], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1649sec]
# Epoch 9930  /  10000
# 	 [Train loss : 0.0002]  [Validation loss : 0.00031] [Test loss : 0.00033], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1649sec]
# Epoch 9931  /  10000
# 	 [Train loss : 0.00022]  [Validation loss : 0.00035] [Test loss : 0.00035], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1649sec]
# Epoch 9932  /  10000
# 	 [Train loss : 0.00026]  [Validation loss : 0.00049] [Test loss : 0.00051], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1650sec]
# Epoch 9933  /  10000
# 	 [Train loss : 0.00032]  [Validation loss : 0.00052] [Test loss : 0.00052], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1650sec]
# Epoch 9934  /  10000
# 	 [Train loss : 0.00037]  [Validation loss : 0.00078] [Test loss : 0.00081], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1650sec]
# Epoch 9935  /  10000
# 	 [Train loss : 0.00046]  [Validation loss : 0.00067] [Test loss : 0.00068], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1650sec]
# Epoch 9936  /  10000
# 	 [Train loss : 0.00049]  [Validation loss : 0.00092] [Test loss : 0.00096], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1650sec]
# Epoch 9937  /  10000
# 	 [Train loss : 0.00052]  [Validation loss : 0.00054] [Test loss : 0.00055], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1650sec]
# Epoch 9938  /  10000
# 	 [Train loss : 0.00043]  [Validation loss : 0.00055] [Test loss : 0.00057], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1651sec]
# Epoch 9939  /  10000
# 	 [Train loss : 0.00032]  [Validation loss : 0.00022] [Test loss : 0.00022], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1651sec]
# Epoch 9940  /  10000
# 	 [Train loss : 0.0002]  [Validation loss : 0.00017] [Test loss : 0.00017], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1651sec]
# Epoch 9941  /  10000
# 	 [Train loss : 0.00015]  [Validation loss : 0.00023] [Test loss : 0.00024], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1651sec]
# Epoch 9942  /  10000
# 	 [Train loss : 0.00018]  [Validation loss : 0.00034] [Test loss : 0.00034], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1651sec]
# Epoch 9943  /  10000
# 	 [Train loss : 0.00025]  [Validation loss : 0.00041] [Test loss : 0.00043], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1651sec]
# Epoch 9944  /  10000
# 	 [Train loss : 0.0003]  [Validation loss : 0.00045] [Test loss : 0.00045], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1652sec]
# Epoch 9945  /  10000
# 	 [Train loss : 0.0003]  [Validation loss : 0.00032] [Test loss : 0.00034], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1652sec]
# Epoch 9946  /  10000
# 	 [Train loss : 0.00026]  [Validation loss : 0.00024] [Test loss : 0.00024], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1652sec]
# Epoch 9947  /  10000
# 	 [Train loss : 0.00019]  [Validation loss : 0.00016] [Test loss : 0.00017], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1652sec]
# Epoch 9948  /  10000
# 	 [Train loss : 0.00015]  [Validation loss : 0.00018] [Test loss : 0.00018], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1652sec]
# Epoch 9949  /  10000
# 	 [Train loss : 0.00016]  [Validation loss : 0.00025] [Test loss : 0.00026], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1652sec]
# Epoch 9950  /  10000
# 	 [Train loss : 0.00019]  [Validation loss : 0.00026] [Test loss : 0.00028], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1653sec]
# Epoch 9951  /  10000
# 	 [Train loss : 0.00022]  [Validation loss : 0.00031] [Test loss : 0.00032], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1653sec]
# Epoch 9952  /  10000
# 	 [Train loss : 0.00022]  [Validation loss : 0.00022] [Test loss : 0.00023], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1653sec]
# Epoch 9953  /  10000
# 	 [Train loss : 0.00019]  [Validation loss : 0.00019] [Test loss : 0.00019], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1653sec]
# Epoch 9954  /  10000
# 	 [Train loss : 0.00016]  [Validation loss : 0.00016] [Test loss : 0.00017], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1653sec]
# Epoch 9955  /  10000
# 	 [Train loss : 0.00015]  [Validation loss : 0.00017] [Test loss : 0.00018], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1653sec]
# Epoch 9956  /  10000
# 	 [Train loss : 0.00016]  [Validation loss : 0.0002] [Test loss : 0.0002], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1654sec]
# Epoch 9957  /  10000
# 	 [Train loss : 0.00017]  [Validation loss : 0.00022] [Test loss : 0.00023], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1654sec]
# Epoch 9958  /  10000
# 	 [Train loss : 0.00018]  [Validation loss : 0.00023] [Test loss : 0.00023], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1654sec]
# Epoch 9959  /  10000
# 	 [Train loss : 0.00018]  [Validation loss : 0.00019] [Test loss : 0.0002], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1654sec]
# Epoch 9960  /  10000
# 	 [Train loss : 0.00017]  [Validation loss : 0.00018] [Test loss : 0.00018], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1654sec]
# Epoch 9961  /  10000
# 	 [Train loss : 0.00015]  [Validation loss : 0.00016] [Test loss : 0.00016], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1654sec]
# Epoch 9962  /  10000
# 	 [Train loss : 0.00015]  [Validation loss : 0.00016] [Test loss : 0.00017], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1655sec]
# Epoch 9963  /  10000
# 	 [Train loss : 0.00015]  [Validation loss : 0.00017] [Test loss : 0.00018], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1655sec]
# Epoch 9964  /  10000
# 	 [Train loss : 0.00016]  [Validation loss : 0.00018] [Test loss : 0.00019], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1655sec]
# Epoch 9965  /  10000
# 	 [Train loss : 0.00016]  [Validation loss : 0.00019] [Test loss : 0.00019], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1655sec]
# Epoch 9966  /  10000
# 	 [Train loss : 0.00016]  [Validation loss : 0.00018] [Test loss : 0.00019], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1655sec]
# Epoch 9967  /  10000
# 	 [Train loss : 0.00016]  [Validation loss : 0.00017] [Test loss : 0.00017], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1655sec]
# Epoch 9968  /  10000
# 	 [Train loss : 0.00015]  [Validation loss : 0.00017] [Test loss : 0.00017], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1656sec]
# Epoch 9969  /  10000
# 	 [Train loss : 0.00015]  [Validation loss : 0.00016] [Test loss : 0.00016], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1656sec]
# Epoch 9970  /  10000
# 	 [Train loss : 0.00015]  [Validation loss : 0.00016] [Test loss : 0.00017], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1656sec]
# Epoch 9971  /  10000
# 	 [Train loss : 0.00015]  [Validation loss : 0.00017] [Test loss : 0.00017], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1656sec]
# Epoch 9972  /  10000
# 	 [Train loss : 0.00015]  [Validation loss : 0.00017] [Test loss : 0.00017], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1656sec]
# Epoch 9973  /  10000
# 	 [Train loss : 0.00015]  [Validation loss : 0.00017] [Test loss : 0.00018], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1656sec]
# Epoch 9974  /  10000
# 	 [Train loss : 0.00015]  [Validation loss : 0.00016] [Test loss : 0.00017], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1656sec]
# Epoch 9975  /  10000
# 	 [Train loss : 0.00015]  [Validation loss : 0.00017] [Test loss : 0.00017], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1657sec]
# Epoch 9976  /  10000
# 	 [Train loss : 0.00015]  [Validation loss : 0.00016] [Test loss : 0.00016], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1657sec]
# Epoch 9977  /  10000
# 	 [Train loss : 0.00015]  [Validation loss : 0.00016] [Test loss : 0.00016], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1657sec]
# Epoch 9978  /  10000
# 	 [Train loss : 0.00015]  [Validation loss : 0.00016] [Test loss : 0.00016], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1657sec]
# Epoch 9979  /  10000
# 	 [Train loss : 0.00015]  [Validation loss : 0.00016] [Test loss : 0.00016], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1657sec]
# Epoch 9980  /  10000
# 	 [Train loss : 0.00015]  [Validation loss : 0.00016] [Test loss : 0.00016], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1658sec]
# Epoch 9981  /  10000
# 	 [Train loss : 0.00015]  [Validation loss : 0.00016] [Test loss : 0.00016], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1658sec]
# Epoch 9982  /  10000
# 	 [Train loss : 0.00015]  [Validation loss : 0.00016] [Test loss : 0.00016], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1658sec]
# Epoch 9983  /  10000
# 	 [Train loss : 0.00015]  [Validation loss : 0.00016] [Test loss : 0.00016], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1658sec]
# Epoch 9984  /  10000
# 	 [Train loss : 0.00015]  [Validation loss : 0.00016] [Test loss : 0.00016], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1658sec]
# Epoch 9985  /  10000
# 	 [Train loss : 0.00014]  [Validation loss : 0.00016] [Test loss : 0.00016], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1658sec]
# Epoch 9986  /  10000
# 	 [Train loss : 0.00014]  [Validation loss : 0.00016] [Test loss : 0.00016], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1659sec]
# Epoch 9987  /  10000
# 	 [Train loss : 0.00014]  [Validation loss : 0.00016] [Test loss : 0.00016], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1659sec]
# Epoch 9988  /  10000
# 	 [Train loss : 0.00014]  [Validation loss : 0.00016] [Test loss : 0.00016], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1659sec]
# Epoch 9989  /  10000
# 	 [Train loss : 0.00014]  [Validation loss : 0.00016] [Test loss : 0.00016], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1659sec]
# Epoch 9990  /  10000
# 	 [Train loss : 0.00015]  [Validation loss : 0.00016] [Test loss : 0.00016], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1659sec]
# Epoch 9991  /  10000
# 	 [Train loss : 0.00015]  [Validation loss : 0.00016] [Test loss : 0.00016], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1659sec]
# Epoch 9992  /  10000
# 	 [Train loss : 0.00014]  [Validation loss : 0.00016] [Test loss : 0.00016], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1659sec]
# Epoch 9993  /  10000
# 	 [Train loss : 0.00014]  [Validation loss : 0.00016] [Test loss : 0.00016], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1660sec]
# Epoch 9994  /  10000
# 	 [Train loss : 0.00014]  [Validation loss : 0.00016] [Test loss : 0.00016], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1660sec]
# Epoch 9995  /  10000
# 	 [Train loss : 0.00014]  [Validation loss : 0.00015] [Test loss : 0.00016], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1660sec]
# Epoch 9996  /  10000
# 	 [Train loss : 0.00014]  [Validation loss : 0.00015] [Test loss : 0.00016], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1660sec]
# Epoch 9997  /  10000
# 	 [Train loss : 0.00014]  [Validation loss : 0.00016] [Test loss : 0.00016], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1660sec]
# Epoch 9998  /  10000
# 	 [Train loss : 0.00014]  [Validation loss : 0.00015] [Test loss : 0.00016], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1660sec]
# Epoch 9999  /  10000
# 	 [Train loss : 0.00014]  [Validation loss : 0.00016] [Test loss : 0.00016], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1661sec]
# Epoch 10000  /  10000
# 	 [Train loss : 0.00014]  [Validation loss : 0.00015] [Test loss : 0.00016], [Test Accuracy : 0.0%],[curr LR = [0.00625]],[elapsed_time = 1661sec]
#
# Train Ended, total_elapsed_time = 1661
# --------------------------------------------------------------------

# %% [markdown]
# ### Plot Loss

# %%
def plot_result(train_loss, val_loss, test_loss):
  plt.figure(figsize=(20,8))
  plt.plot(train_loss, label='Train Loss', linewidth='3')
  plt.plot(val_loss, label='Validation Loss', linewidth='3')
  plt.plot(test_loss, label='Test Loss', linewidth='3')
  plt.grid()
  plt.rc('xtick', labelsize=12)
  plt.rc('ytick', labelsize=12)
  plt.legend()
  plt.rc('legend', fontsize=15)
  plt.xlabel('Number of Eopch')
  plt.ylabel('Cross Entropy Loss')
  plt.rc('axes', labelsize=17)

# %% [markdown]
# ### Plot

# %%
plot_result(train_losses, valid_losses, test_losses)

# %% [markdown]
# ## 3D Visualize Graph

# %%
def visual_graph(model):
  x = np.linspace(-1, 1, 100)
  y = np.linspace(-1, 1, 100)
  xx,yy = np.meshgrid(x,y)
  xx = xx.reshape(-1,1)
  yy = yy.reshape(-1,1)
  inp_np = np.hstack((xx,yy))
  inp_tensor = torch.Tensor(inp_np)
  inp_tensor = inp_tensor.to(device)
  zz = model(inp_tensor)
  pred_output = zz.detach().cpu().numpy()
  fig = plt.figure(figsize=(9, 6))
  ax = fig.add_subplot(111, projection='3d')
  xx = xx.reshape(100,100)
  yy = yy.reshape(100,100)
  pred_output = pred_output.reshape(100,100)
  surf = ax.plot_surface(xx, yy, pred_output, cmap='viridis')
  surf.set_clim(-1.0, 1.0)
  ax.view_init(30,-60)
  ax.set_zticks([-1,1])
  ax.zaxis.set_major_locator(ticker.MultipleLocator(0.25))
  plt.tight_layout()
  plt.show()

# %% [markdown]
# ## Plot 3D Graph

# %%
visual_graph(model)
